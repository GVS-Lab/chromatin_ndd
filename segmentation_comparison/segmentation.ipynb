# %%
import os

from readlif.reader import LifFile 
import sys
import pandas as pd
import matplotlib.pyplot as plt

import segmentation

segmenter = segmentation.Segmenter(n_jobs=4)

# %%
images = segmenter.load_images(input_dir = 'experiment2\JC_Plate2_both_high', inclusion1='')
len(images)
# Out:
# 133

# %%
segmenter.create_otsu_masks(images, thresh_value = 1, output_path='experiment2\JC_Plate2_both_high\otsu_masks')

# %%
images = segmenter.load_images(input_dir ='experiment2\JC_Plate2_both_high\otsu_masks', inclusion1='otsu_mask')

# %%
nr = 25

mid_z = images[nr]['image'].shape[0] // 2

plt.imshow(images[nr]['image'][mid_z-8], cmap='Blues')
