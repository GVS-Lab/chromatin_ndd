# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import seaborn as sns
import sklearn
from sklearn import preprocessing

import os
from os import path

# %%
df_all = pd.DataFrame()
df_list = []

for folder in os.listdir():
    if not os.path.isdir(folder) or 'ipynb' in folder or folder == 'all_features':
        continue
    print(folder)
    df = pd.read_pickle(path.join(folder, 'regionprops_3d_extended.pkl'))
    df['condition'] = str(folder)
    df_list.append(df)

df_all = pd.concat(df_list)
# Out:
# JC_Plate2_both_high
# /tmp/ipykernel_1158987/667520340.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['condition'] = str(folder)
# JC_Plate2_BSA
# /tmp/ipykernel_1158987/667520340.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['condition'] = str(folder)
# JC_Plate2_Control
# /tmp/ipykernel_1158987/667520340.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['condition'] = str(folder)
# JC_Plate2_tnfa_high
# /tmp/ipykernel_1158987/667520340.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['condition'] = str(folder)
# JC_Plate2_both_low
# /tmp/ipykernel_1158987/667520340.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['condition'] = str(folder)
# JC_Plate2_mcp_high
# /tmp/ipykernel_1158987/667520340.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['condition'] = str(folder)
# JC_Plate2_tnfa_low
# /tmp/ipykernel_1158987/667520340.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['condition'] = str(folder)
# JC_Plate2_mcp_low
# /tmp/ipykernel_1158987/667520340.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['condition'] = str(folder)

# %%
df_all.to_pickle('dataframe_labeled.pkl')

# %%
df_all=pd.read_pickle('dataframe_labeled.pkl')

# %%
df_all.iloc[0].condition
# Out:
# 'JC_Plate2_both_high'

# %%
df_all['condition'] = df_all['condition'].apply(lambda x: '_'.join(x.rsplit('_')[2:]))
df_all.iloc[0].condition

df = df_all

# %%
std_lower = np.std(df[df.area < np.percentile(df.area, 50)].area)
std_upper = np.std(df[df.area > np.percentile(df.area, 50)].area)

# %%
sns.displot(df.area)
plt.axvline(x=np.median(df.area) +  1.5*std_upper, color='r', linestyle='--')
plt.axvline(x=np.median(df.area) -  1.5*std_lower, color='r', linestyle='--')


plt.title('Distribution of area')
plt.xlabel('area')
plt.ylabel('absolute frequency')
plt.show()

# %%
df = df[(df.area >= (np.median(df.area) - 1.5 * std_lower)) & (df.area <= (np.median(df.area) +  1.5*std_upper))]

# %%
sns.displot(df.area)

plt.title('Distribution of area')
plt.xlabel('area')
plt.ylabel('absolute frequency')
# Out:
# Text(5.069444444444445, 0.5, 'absolute frequency')

# %%
sns.displot(df.bbox_area)
plt.axvline(x=np.percentile(df.bbox_area, 97.5), color='r', linestyle='--')

plt.title('Distribution of bbox_area')
plt.xlabel('bbox_area')
plt.ylabel('absolute frequency')
# Out:
# Text(5.069444444444445, 0.5, 'absolute frequency')

# %%
df = df[df.bbox_area <= np.percentile(df.bbox_area, 97.5)]

# %%
sns.displot(df.area)

plt.title('Distribution of area')
plt.xlabel('area')
plt.ylabel('absolute frequency')
# Out:
# Text(5.069444444444445, 0.5, 'absolute frequency')

# %%
image_features = ['image', 'slice', 'intensity_image', 'convex_image']
df_images = df[image_features]
df = df.drop(columns=image_features)
df_images.to_pickle('dataframe_images.pkl')
df.to_pickle('dataframe_no_images.pkl')

# %%
df = pd.read_pickle('dataframe_no_images.pkl')
df = df.reset_index(drop=True)

# %%
columns = df.columns[0:-1]
df[columns] = df[columns].apply(pd.to_numeric, errors='ignore')

# %%
columns = df.columns[0:-1]
df[columns] = df[columns].applymap(lambda x: x[0] if isinstance(x, np.ndarray) and len(x) > 0 else x)
#some entries are of dtype np.ndarray but only contain one value - extracting this value

# %%
cols = [col for col in df.columns if ('bbox' not in col and 'centroid' not in col and 'coords' not in col and 'label' not in col) or ('local' in col)]
df = df[cols]
#drop features with no biological relevance

# %%
df = df[~df.isin([np.inf, -np.inf]).any(axis=1)]
df
#remove nuclei with inf values (only 6 so just remove)
# Out:
#       convex_area      area  equivalent_diameter  euler_number    extent  \
# 0         94928.0   84631.0            54.472455             1  0.492591
# 1         79274.0   71684.0            51.539619             1  0.488297
# 2         89689.0   78307.0            53.080376             1  0.468186
# 3        142797.0  124167.0            61.896941             1  0.489927
# 4         81335.0   71991.0            51.613090             1  0.485769
# ...           ...       ...                  ...           ...       ...
# 2415      92276.0   82400.0            53.989528             1  0.493561
# 2416     120080.0  108652.0            59.203362             1  0.502423
# 2417     137901.0  120933.0            61.354827             1  0.468616
# 2418      98152.0   85422.0            54.641637             1  0.501774
# 2419      71822.0   62120.0            49.137261             1  0.462512
#
#       inertia_tensor-0-0  inertia_tensor-0-1  inertia_tensor-0-2  \
# 0            1210.934824           10.504096           -5.912663
# 1             990.552967           -6.172104            0.189872
# 2             839.284096            7.381286          -12.764262
# 3            1580.128968           -9.276239           -0.824784
# 4            1112.981524            5.457222           -6.909267
# ...                  ...                 ...                 ...
# 2415         1091.454852           14.240921           -3.970065
# 2416         1367.946176           17.134449           13.429104
# 2417         1588.079753            9.522492           -2.212826
# 2418         1282.769309           -0.440234          -23.558704
# 2419         1105.115701           -4.498792           -0.672572
#
#       inertia_tensor-1-0  inertia_tensor-1-1  ...  \
# 0              10.504096          688.460442  ...
# 1              -6.172104          568.403124  ...
# 2               7.381286          474.665660  ...
# 3              -9.276239          641.895742  ...
# 4               5.457222          481.662379  ...
# ...                  ...                 ...  ...
# 2415           14.240921          553.777438  ...
# 2416           17.134449          593.433802  ...
# 2417            9.522492          813.235703  ...
# 2418           -0.440234          866.821551  ...
# 2419           -4.498792          599.589892  ...
#
#       hc_foci_ratio_d2b_volume_variance  hc_foci_d_nearest_neighbor_mean  \
# 0                            134.090297                         1.590401
# 1                             39.368828                         1.547823
# 2                           1574.010810                         1.344342
# 3                            862.757148                         1.229514
# 4                           4542.094898                         1.677228
# ...                                 ...                              ...
# 2415                         791.439100                         1.230201
# 2416                         733.746690                         1.103362
# 2417                        2575.781619                         1.541557
# 2418                          73.351815                         1.141703
# 2419                        1020.116935                         1.485999
#
#       hc_foci_d_nearest_neighbor_variance  \
# 0                                0.508630
# 1                                0.315031
# 2                                0.276930
# 3                                0.343294
# 4                                0.736829
# ...                                   ...
# 2415                             0.384133
# 2416                             0.388680
# 2417                             0.334541
# 2418                             0.381132
# 2419                             0.293150
#
#       hc_foci_ratio_nearest_neighbor_volume_mean  \
# 0                                      30.376361
# 1                                       9.624052
# 2                                      16.192628
# 3                                       4.079367
# 4                                      26.805745
# ...                                          ...
# 2415                                    9.860227
# 2416                                    7.795943
# 2417                                    9.877622
# 2418                                    7.576689
# 2419                                   11.717596
#
#       hc_foci_ratio_nearest_neighbor_volume_variance  \
# 0                                         380.131333
# 1                                          69.551389
# 2                                         164.369675
# 3                                           9.514733
# 4                                         182.368657
# ...                                              ...
# 2415                                       52.983905
# 2416                                       25.734088
# 2417                                       26.288559
# 2418                                       32.974505
# 2419                                      110.337308
#
#       hc_foci_d_nearest_neighbor(verts)_mean  \
# 0                                   0.589293
# 1                                   0.755844
# 2                                   0.907164
# 3                                   0.586685
# 4                                   0.971651
# ...                                      ...
# 2415                                0.483157
# 2416                                0.826560
# 2417                                0.850100
# 2418                                0.432902
# 2419                                1.053670
#
#       hc_foci_d_nearest_neighbor(verts)_variance  \
# 0                                       0.225449
# 1                                       0.205321
# 2                                       0.452996
# 3                                       0.396029
# 4                                       0.669677
# ...                                          ...
# 2415                                    0.182969
# 2416                                    0.404081
# 2417                                    0.382637
# 2418                                    0.178480
# 2419                                    0.551751
#
#       hc_foci_ratio_nearest_neighbor(verts)_mean_count  \
# 0                                             0.039286
# 1                                             0.034357
# 2                                             0.047745
# 3                                             0.011734
# 4                                             0.064777
# ...                                                ...
# 2415                                          0.021007
# 2416                                          0.023616
# 2417                                          0.027423
# 2418                                          0.014928
# 2419                                          0.061981
#
#       hc_foci_ratio_nearest_neighbor(verts)_variance_count  condition
# 0                                              0.015030     both_high
# 1                                              0.009333     both_high
# 2                                              0.023842     both_high
# 3                                              0.007921     both_high
# 4                                              0.044645     both_high
# ...                                                 ...           ...
# 2415                                           0.007955       mcp_low
# 2416                                           0.011545       mcp_low
# 2417                                           0.012343       mcp_low
# 2418                                           0.006154       mcp_low
# 2419                                           0.032456       mcp_low
#
# [2417 rows x 991 columns]

# %%
from sklearn.impute import KNNImputer


#Drop fully empty features
df = df.dropna(axis=1, how='all')

condition = df['condition'].reset_index(drop=True)
features = df.drop(columns=['condition']).reset_index(drop=True)

imputer = KNNImputer(n_neighbors=5, keep_empty_features=True)
features_imputed = pd.DataFrame(imputer.fit_transform(features), columns=features.columns)

df_imputed = pd.concat([features_imputed, condition], axis=1, ignore_index=False)

print(features_imputed.shape, condition.shape)
# Out:
# (2417, 974) (2417,)

# %%
df_imputed.columns[df_imputed.isna().any()]
# Out:
# Index([], dtype='object')

# %%
df_imputed
# Out:
#       convex_area      area  equivalent_diameter  euler_number    extent  \
# 0         94928.0   84631.0            54.472455           1.0  0.492591
# 1         79274.0   71684.0            51.539619           1.0  0.488297
# 2         89689.0   78307.0            53.080376           1.0  0.468186
# 3        142797.0  124167.0            61.896941           1.0  0.489927
# 4         81335.0   71991.0            51.613090           1.0  0.485769
# ...           ...       ...                  ...           ...       ...
# 2412      92276.0   82400.0            53.989528           1.0  0.493561
# 2413     120080.0  108652.0            59.203362           1.0  0.502423
# 2414     137901.0  120933.0            61.354827           1.0  0.468616
# 2415      98152.0   85422.0            54.641637           1.0  0.501774
# 2416      71822.0   62120.0            49.137261           1.0  0.462512
#
#       inertia_tensor-0-0  inertia_tensor-0-1  inertia_tensor-0-2  \
# 0            1210.934824           10.504096           -5.912663
# 1             990.552967           -6.172104            0.189872
# 2             839.284096            7.381286          -12.764262
# 3            1580.128968           -9.276239           -0.824784
# 4            1112.981524            5.457222           -6.909267
# ...                  ...                 ...                 ...
# 2412         1091.454852           14.240921           -3.970065
# 2413         1367.946176           17.134449           13.429104
# 2414         1588.079753            9.522492           -2.212826
# 2415         1282.769309           -0.440234          -23.558704
# 2416         1105.115701           -4.498792           -0.672572
#
#       inertia_tensor-1-0  inertia_tensor-1-1  ...  \
# 0              10.504096          688.460442  ...
# 1              -6.172104          568.403124  ...
# 2               7.381286          474.665660  ...
# 3              -9.276239          641.895742  ...
# 4               5.457222          481.662379  ...
# ...                  ...                 ...  ...
# 2412           14.240921          553.777438  ...
# 2413           17.134449          593.433802  ...
# 2414            9.522492          813.235703  ...
# 2415           -0.440234          866.821551  ...
# 2416           -4.498792          599.589892  ...
#
#       hc_foci_ratio_d2b_volume_variance  hc_foci_d_nearest_neighbor_mean  \
# 0                            134.090297                         1.590401
# 1                             39.368828                         1.547823
# 2                           1574.010810                         1.344342
# 3                            862.757148                         1.229514
# 4                           4542.094898                         1.677228
# ...                                 ...                              ...
# 2412                         791.439100                         1.230201
# 2413                         733.746690                         1.103362
# 2414                        2575.781619                         1.541557
# 2415                          73.351815                         1.141703
# 2416                        1020.116935                         1.485999
#
#       hc_foci_d_nearest_neighbor_variance  \
# 0                                0.508630
# 1                                0.315031
# 2                                0.276930
# 3                                0.343294
# 4                                0.736829
# ...                                   ...
# 2412                             0.384133
# 2413                             0.388680
# 2414                             0.334541
# 2415                             0.381132
# 2416                             0.293150
#
#       hc_foci_ratio_nearest_neighbor_volume_mean  \
# 0                                      30.376361
# 1                                       9.624052
# 2                                      16.192628
# 3                                       4.079367
# 4                                      26.805745
# ...                                          ...
# 2412                                    9.860227
# 2413                                    7.795943
# 2414                                    9.877622
# 2415                                    7.576689
# 2416                                   11.717596
#
#       hc_foci_ratio_nearest_neighbor_volume_variance  \
# 0                                         380.131333
# 1                                          69.551389
# 2                                         164.369675
# 3                                           9.514733
# 4                                         182.368657
# ...                                              ...
# 2412                                       52.983905
# 2413                                       25.734088
# 2414                                       26.288559
# 2415                                       32.974505
# 2416                                      110.337308
#
#       hc_foci_d_nearest_neighbor(verts)_mean  \
# 0                                   0.589293
# 1                                   0.755844
# 2                                   0.907164
# 3                                   0.586685
# 4                                   0.971651
# ...                                      ...
# 2412                                0.483157
# 2413                                0.826560
# 2414                                0.850100
# 2415                                0.432902
# 2416                                1.053670
#
#       hc_foci_d_nearest_neighbor(verts)_variance  \
# 0                                       0.225449
# 1                                       0.205321
# 2                                       0.452996
# 3                                       0.396029
# 4                                       0.669677
# ...                                          ...
# 2412                                    0.182969
# 2413                                    0.404081
# 2414                                    0.382637
# 2415                                    0.178480
# 2416                                    0.551751
#
#       hc_foci_ratio_nearest_neighbor(verts)_mean_count  \
# 0                                             0.039286
# 1                                             0.034357
# 2                                             0.047745
# 3                                             0.011734
# 4                                             0.064777
# ...                                                ...
# 2412                                          0.021007
# 2413                                          0.023616
# 2414                                          0.027423
# 2415                                          0.014928
# 2416                                          0.061981
#
#       hc_foci_ratio_nearest_neighbor(verts)_variance_count  condition
# 0                                              0.015030     both_high
# 1                                              0.009333     both_high
# 2                                              0.023842     both_high
# 3                                              0.007921     both_high
# 4                                              0.044645     both_high
# ...                                                 ...           ...
# 2412                                           0.007955       mcp_low
# 2413                                           0.011545       mcp_low
# 2414                                           0.012343       mcp_low
# 2415                                           0.006154       mcp_low
# 2416                                           0.032456       mcp_low
#
# [2417 rows x 975 columns]

# %%
df_imputed.to_pickle('dataframe_knn_imputed.pkl')

# %% [markdown]
# <h4> Random Forest Classifier </h4>

# %%
def plot_feature_importances(feature_importances):
    top20 = feature_importances['Feature Importance'].nlargest(20)
    plt.figure(figsize=(10, 6))
    plt.barh(top20.index, top20.values, align='center')
    plt.yticks(top20.index, top20.index)
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature')
    plt.title('Top 20 Feature Importances')
    plt.gca().invert_yaxis()  # Invert y-axis to display highest importance at the top
    plt.show()
    
def plot_confusion_matrix(cf):
    sns.heatmap(cf, annot=True, fmt=".2f", cmap="YlGnBu")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix")
    plt.show()

def plot_accuracies(df_ac):
    plt.figure(figsize=(10, 6))
    plt.bar(df_ac['Model'], df_ac['Accuracy'])
    plt.xlabel('Model')
    plt.ylabel('Accuracy')
    plt.title('Accuracies for RFCs')
    plt.tight_layout()  
    plt.xticks(rotation=90)
    plt.show()

def all_possible_rfc(df, output_dir, kfold = 20, n_jobs = 96, compute_pairs=False, param_grid=None, n_estimators=100):

    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import KFold
    from sklearn.metrics import confusion_matrix
    from sklearn.model_selection import GridSearchCV
    import numpy as np 
    import pandas as pd
    from os.path import join
    import itertools

    # !mkdir -p $output_dir

    accuracies_df = pd.DataFrame()


    columns = df.columns[0:-1]
    X = df[columns].to_numpy()
    y = df.condition.to_numpy()

    model = RandomForestClassifier(criterion="entropy", n_estimators=n_estimators, n_jobs=n_jobs)

    if param_grid:
        grid_search = GridSearchCV(model, param_grid, cv=kfold, n_jobs=n_jobs)
        grid_search.fit(X, y)
        best_params = grid_search.best_params_
        print("Best Parameters:", best_params)
        model = grid_search.best_estimator_

    kfold = KFold(n_splits=kfold, shuffle=True, random_state=42)  # Adjust the number of splits as needed
    accuracies = []
    train_acc = []
    feature_importances = np.zeros(X.shape[1])  # Initialize array to store feature importances
    confusion_matrices = []
    
    for train_index, test_index in kfold.split(X):
        X_train, X_val = X[train_index], X[test_index]
        y_train, y_val = y[train_index], y[test_index]
    
        model.fit(X_train, y_train)
        train_acc.append(model.score(X_train, y_train))
        
        # Evaluate the model
        accuracy = model.score(X_val, y_val)
        accuracies.append(accuracy)
        
        # Predict on validation set
        y_pred = model.predict(X_val)
        
        # Calculate confusion matrix
        cm = confusion_matrix(y_val, y_pred)
        confusion_matrices.append(cm)
        
        # Accumulate feature importances
        feature_importances += model.feature_importances_
    
    average_accuracy = np.mean(accuracies)
    avg_train_acc = np.mean(train_acc)
    accuracies_df = pd.concat([accuracies_df, pd.DataFrame({'Model': ['all'], 'Accuracy': [average_accuracy], 'Train-Accuracy': [avg_train_acc]})], ignore_index=True)
    print("Average Train Accuracy:", avg_train_acc)
    print("Average Accuracy:", average_accuracy)
    
    # Calculate average confusion matrix
    average_confusion_matrix = np.mean(confusion_matrices, axis=0)
    
    # Normalize the confusion matrix
    sum_true_positives = average_confusion_matrix.sum(axis=1, keepdims=True)
    normalized_confusion_matrix = average_confusion_matrix / sum_true_positives
    
    # Display normalized confusion matrix as DataFrame
    confusion_matrix_df = pd.DataFrame(normalized_confusion_matrix, columns=model.classes_, index=model.classes_)
    confusion_matrix_df.to_pickle(join(output_dir, 'confusion_matrix.pkl'))
    
    # Average feature importances across all folds
    average_feature_importances = feature_importances / kfold.n_splits
    
    # Create DataFrame for feature importances
    feature_importance_df = pd.DataFrame(average_feature_importances, columns=["Feature Importance"], index=columns)
    feature_importance_df.to_pickle(join(output_dir, 'feature_importance.pkl'))

    plot_feature_importances(feature_importance_df)
    plot_confusion_matrix(confusion_matrix_df)

    if compute_pairs:
        # Generate all possible combinations of pairs
        conditions = set(df.condition)
        pairs = set()
        for pair in itertools.combinations(conditions, 2):
            pairs.add(tuple(sorted(pair)))
        pairs = list(pairs)
       
        for pair in pairs:
            foldername = pair[0] + '-' + pair[1]
            foldername = join(output_dir, foldername)
            print(foldername)
            # !mkdir -p $foldername
            df_curr = df[(df['condition'] == pair[0]) | (df['condition'] == pair[1])]
        
            X = df_curr[columns].to_numpy()
            y = df_curr.condition.to_numpy()
    
            accuracies = []
            train_acc = []
            feature_importances = np.zeros(X.shape[1])  # Initialize array to store feature importances
            confusion_matrices = []
            
            for train_index, test_index in kfold.split(X):
                X_train, X_val = X[train_index], X[test_index]
                y_train, y_val = y[train_index], y[test_index]
            
                model.fit(X_train, y_train)
                train_acc.append(model.score(X_train, y_train))
                
                # Evaluate the model
                accuracy = model.score(X_val, y_val)
                accuracies.append(accuracy)
                
                # Predict on validation set
                y_pred = model.predict(X_val)
                
                # Calculate confusion matrix
                cm = confusion_matrix(y_val, y_pred)
                confusion_matrices.append(cm)
                
                # Accumulate feature importances
                feature_importances += model.feature_importances_
            
            average_accuracy = np.mean(accuracies)
            avg_train_acc = np.mean(train_acc)
            accuracies_df = pd.concat([accuracies_df, pd.DataFrame({'Model': [foldername.rsplit('/')[-1]], 'Accuracy': [average_accuracy], 'Train-Accuracy': [avg_train_acc]})], ignore_index=True)
            print("Average Accuracy:", average_accuracy)
            
            # Calculate average confusion matrix
            average_confusion_matrix = np.mean(confusion_matrices, axis=0)
            
            # Normalize the confusion matrix
            sum_true_positives = average_confusion_matrix.sum(axis=1, keepdims=True)
            normalized_confusion_matrix = average_confusion_matrix / sum_true_positives
            
            # Display normalized confusion matrix as DataFrame
            confusion_matrix_df = pd.DataFrame(normalized_confusion_matrix, columns=model.classes_, index=model.classes_)
            confusion_matrix_df.to_pickle(join(foldername,'confusion_matrix.pkl'))
            
            # Average feature importances across all folds
            average_feature_importances = feature_importances / kfold.n_splits
            
            # Create DataFrame for feature importances
            feature_importance_df = pd.DataFrame(average_feature_importances, columns=["Feature Importance"], index=columns)
            feature_importance_df.to_pickle(join(foldername,'feature_importance.pkl'))
    
        plot_accuracies(accuracies_df)

# %%
df = pd.read_pickle('dataframe_knn_imputed.pkl')
df = df.reset_index(drop=True)


all_possible_rfc(df, 'all_features', compute_pairs=False, n_jobs=96)
# Out:
# Average Train Accuracy: 1.0
# Average Accuracy: 0.501026170798898

# %% [markdown]
# <h4>Scale dataset, low variance filtering, correlation filtering</h4>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Assuming df is your pandas DataFrame

df = pd.read_pickle('dataframe_knn_imputed.pkl')
df = df.reset_index(drop=True)

condition = df['condition'].reset_index(drop=True)
features = df.drop(columns=['condition']).reset_index(drop=True)

scaler = MinMaxScaler(feature_range=(0, 1))  # Scale features to range from 0 to 1
df_normalized = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)

# Concatenate the condition column back to the normalized features DataFrame
#df_normalized = pd.concat([condition, df_normalized], axis=1)

# %%
df_normalized.describe()
# Out:
#        convex_area         area  equivalent_diameter  euler_number  \
# count  2417.000000  2417.000000          2417.000000   2417.000000
# mean      0.348376     0.442312             0.547445      0.973151
# std       0.164780     0.201344             0.192010      0.043024
# min       0.000000     0.000000             0.000000      0.000000
# 25%       0.221860     0.286781             0.404359      0.978723
# 50%       0.319361     0.406987             0.531203      0.978723
# 75%       0.461559     0.589252             0.697448      0.978723
# max       1.000000     1.000000             1.000000      1.000000
#
#             extent  inertia_tensor-0-0  inertia_tensor-0-1  \
# count  2417.000000         2417.000000         2417.000000
# mean      0.649965            0.165764            0.412023
# std       0.121856            0.084890            0.093574
# min       0.000000            0.000000            0.000000
# 25%       0.586857            0.111053            0.349457
# 50%       0.657840            0.155062            0.414018
# 75%       0.731236            0.203463            0.471882
# max       1.000000            1.000000            1.000000
#
#        inertia_tensor-0-2  inertia_tensor-1-0  inertia_tensor-1-1  ...  \
# count         2417.000000         2417.000000         2417.000000  ...
# mean             0.477035            0.412023            0.084794  ...
# std              0.081553            0.093574            0.058146  ...
# min              0.000000            0.000000            0.000000  ...
# 25%              0.422960            0.349457            0.051543  ...
# 50%              0.478779            0.414018            0.076309  ...
# 75%              0.529282            0.471882            0.108804  ...
# max              1.000000            1.000000            1.000000  ...
#
#        hc_foci_ratio_d2b_volume_mean  hc_foci_ratio_d2b_volume_variance  \
# count                    2417.000000                        2417.000000
# mean                        0.071240                           0.018575
# std                         0.086712                           0.044905
# min                         0.000000                           0.000000
# 25%                         0.017759                           0.001141
# 50%                         0.046628                           0.005482
# 75%                         0.092626                           0.017574
# max                         1.000000                           1.000000
#
#        hc_foci_d_nearest_neighbor_mean  hc_foci_d_nearest_neighbor_variance  \
# count                      2417.000000                          2417.000000
# mean                          0.118371                             0.117878
# std                           0.069984                             0.064294
# min                           0.000000                             0.000000
# 25%                           0.073553                             0.076990
# 50%                           0.105687                             0.105759
# 75%                           0.145047                             0.143064
# max                           1.000000                             1.000000
#
#        hc_foci_ratio_nearest_neighbor_volume_mean  \
# count                                 2417.000000
# mean                                     0.005915
# std                                      0.026306
# min                                      0.000000
# 25%                                      0.001762
# 50%                                      0.003023
# 75%                                      0.005437
# max                                      1.000000
#
#        hc_foci_ratio_nearest_neighbor_volume_variance  \
# count                                     2417.000000
# mean                                         0.006787
# std                                          0.036033
# min                                          0.000000
# 25%                                          0.000398
# 50%                                          0.000986
# 75%                                          0.002905
# max                                          1.000000
#
#        hc_foci_d_nearest_neighbor(verts)_mean  \
# count                             2417.000000
# mean                                 0.188713
# std                                  0.078707
# min                                  0.000000
# 25%                                  0.137838
# 50%                                  0.173578
# 75%                                  0.223491
# max                                  1.000000
#
#        hc_foci_d_nearest_neighbor(verts)_variance  \
# count                                 2417.000000
# mean                                     0.125045
# std                                      0.087666
# min                                      0.000000
# 25%                                      0.066539
# 50%                                      0.104544
# 75%                                      0.158382
# max                                      1.000000
#
#        hc_foci_ratio_nearest_neighbor(verts)_mean_count  \
# count                                       2417.000000
# mean                                           0.030621
# std                                            0.047577
# min                                            0.000000
# 25%                                            0.012057
# 50%                                            0.019349
# 75%                                            0.034630
# max                                            1.000000
#
#        hc_foci_ratio_nearest_neighbor(verts)_variance_count
# count                                        2417.000000
# mean                                            0.037306
# std                                             0.059953
# min                                             0.000000
# 25%                                             0.012134
# 50%                                             0.021462
# 75%                                             0.041583
# max                                             1.000000
#
# [8 rows x 974 columns]

# %%
from sklearn.feature_selection import VarianceThreshold
import pandas as pd

# Assuming df_normalized is your DataFrame

# Initialize VarianceThreshold with threshold 0.005
selector = VarianceThreshold(threshold=0.005)

# Fit the selector to your data
selector.fit(df_normalized)

# Get boolean mask of features selected
selected_features_mask = selector.get_support()

# Get the names of removed features
removed_features = df_normalized.columns[~selected_features_mask]

# Remove the low variance features from the DataFrame
df_filtered = df_normalized.loc[:, selected_features_mask]

# Print the removed features
print("Removed features:")
print(removed_features, len(removed_features))
# Out:
# Removed features:
# Index(['euler_number', 'inertia_tensor-1-1', 'inertia_tensor-1-2',
#        'inertia_tensor-2-1', 'inertia_tensor-2-2', 'max_intensity-0',
#        'max_intensity-1', 'max_intensity-2', 'mean_intensity-2',
#        'min_intensity-0',
#        ...
#        'hc_foci_volume_mean', 'hc_foci_volume_variance',
#        'hc_foci_mean_intensity_variance', 'hc_foci_ratio_d2b_volume_variance',
#        'hc_foci_d_nearest_neighbor_mean',
#        'hc_foci_d_nearest_neighbor_variance',
#        'hc_foci_ratio_nearest_neighbor_volume_mean',
#        'hc_foci_ratio_nearest_neighbor_volume_variance',
#        'hc_foci_ratio_nearest_neighbor(verts)_mean_count',
#        'hc_foci_ratio_nearest_neighbor(verts)_variance_count'],
#       dtype='object', length=521) 521

# %%
df_filtered = pd.concat([df_filtered, condition], axis=1)
df_filtered
# Out:
#       convex_area      area  equivalent_diameter    extent  \
# 0        0.341587  0.445533             0.568653  0.684182
# 1        0.248008  0.336380             0.458723  0.671198
# 2        0.310268  0.392217             0.516474  0.610379
# 3        0.627746  0.778852             0.846943  0.676125
# 4        0.260328  0.338968             0.461476  0.663553
# ...           ...       ...                  ...       ...
# 2412     0.325733  0.426724             0.550552  0.687117
# 2413     0.491945  0.648049             0.745981  0.713917
# 2414     0.598478  0.751587             0.826623  0.611679
# 2415     0.360860  0.452202             0.574995  0.711954
# 2416     0.203460  0.255748             0.368676  0.593218
#
#       inertia_tensor-0-0  inertia_tensor-0-1  inertia_tensor-0-2  \
# 0               0.171154            0.490094            0.435584
# 1               0.114398            0.351761            0.478840
# 2               0.075442            0.464190            0.387019
# 3               0.266233            0.326011            0.471648
# 4               0.145928            0.448229            0.428520
# ...                  ...                 ...                 ...
# 2412            0.140384            0.521092            0.449354
# 2413            0.211589            0.545095            0.572682
# 2414            0.268281            0.481952            0.461809
# 2415            0.189654            0.399308            0.310507
# 2416            0.143902            0.365642            0.472727
#
#       inertia_tensor-1-0  inertia_tensor-2-0  inertia_tensor_eigvals-0  ...  \
# 0               0.490094            0.435584                  0.171053  ...
# 1               0.351761            0.478840                  0.114234  ...
# 2               0.464190            0.387019                  0.075375  ...
# 3               0.326011            0.471648                  0.266087  ...
# 4               0.448229            0.428520                  0.145781  ...
# ...                  ...                 ...                       ...  ...
# 2412            0.521092            0.449354                  0.140314  ...
# 2413            0.545095            0.572682                  0.211594  ...
# 2414            0.481952            0.461809                  0.268151  ...
# 2415            0.399308            0.310507                  0.189646  ...
# 2416            0.365642            0.472727                  0.143728  ...
#
#       lamin_hole_ratio_nearest_neighbor(verts)_mean_count  \
# 0                                              0.012857
# 1                                              0.021071
# 2                                              0.067895
# 3                                              0.017753
# 4                                              0.318787
# ...                                                 ...
# 2412                                           0.018890
# 2413                                           0.132006
# 2414                                           0.024977
# 2415                                           0.152270
# 2416                                           0.020999
#
#       lamin_hole_ratio_nearest_neighbor(verts)_variance_count  hc_foci_count  \
# 0                                              0.017794               0.1750
# 1                                              0.007305               0.2625
# 2                                              0.030514               0.2250
# 3                                              0.001747               0.6125
# 4                                              0.000000               0.1750
# ...                                                 ...                  ...
# 2412                                           0.018767               0.2750
# 2413                                           0.003549               0.4250
# 2414                                           0.017994               0.3750
# 2415                                           0.527712               0.3500
# 2416                                           0.004813               0.2000
#
#       hc_foci_mean_intensity_mean  hc_foci_d2b_mean  hc_foci_d2b_variance  \
# 0                        0.397086          0.046356              0.019729
# 1                        0.288563          0.013415              0.003580
# 2                        0.381936          0.168146              0.171746
# 3                        0.317876          0.322092              0.345231
# 4                        0.358974          0.130303              0.218237
# ...                           ...               ...                   ...
# 2412                     0.352349          0.104421              0.173986
# 2413                     0.487063          0.269539              0.246557
# 2414                     0.373310          0.240983              0.277607
# 2415                     0.200610          0.080584              0.033944
# 2416                     0.468700          0.315706              0.211311
#
#       hc_foci_ratio_d2b_volume_mean  hc_foci_d_nearest_neighbor(verts)_mean  \
# 0                          0.027430                                0.146752
# 1                          0.008717                                0.202305
# 2                          0.084650                                0.252778
# 3                          0.078062                                0.145883
# 4                          0.116123                                0.274287
# ...                             ...                                     ...
# 2412                       0.043640                                0.111351
# 2413                       0.086177                                0.225892
# 2414                       0.135323                                0.233744
# 2415                       0.019482                                0.094588
# 2416                       0.125724                                0.301645
#
#       hc_foci_d_nearest_neighbor(verts)_variance  condition
# 0                                       0.067056  both_high
# 1                                       0.061069  both_high
# 2                                       0.134735  both_high
# 3                                       0.117792  both_high
# 4                                       0.199183  both_high
# ...                                          ...        ...
# 2412                                    0.054421    mcp_low
# 2413                                    0.120186    mcp_low
# 2414                                    0.113808    mcp_low
# 2415                                    0.053086    mcp_low
# 2416                                    0.164108    mcp_low
#
# [2417 rows x 454 columns]

# %%
all_possible_rfc(df_filtered, 'all_features', compute_pairs=False, n_jobs=96)
# Out:
# Average Train Accuracy: 1.0
# Average Accuracy: 0.4923519283746557

# %%
#https://www.kaggle.com/code/oldwine357/removing-highly-correlated-features/notebook

def remove_collinear_features(x, threshold):
    '''
    Objective:
        Remove collinear features in a dataframe with a correlation coefficient
        greater than the threshold. Removing collinear features can help a model 
        to generalize and improves the interpretability of the model.

    Inputs: 
        x: features dataframe
        threshold: features with correlations greater than this value are removed

    Output: 
        dataframe that contains only the non-highly-collinear features
    '''

    # Calculate the correlation matrix
    corr_matrix = x.corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # Iterate through the correlation matrix and compare correlations
    for i in iters:
        for j in range(i+1):
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)

            # If correlation exceeds the threshold
            if val >= threshold:
                # Print the correlated features and the correlation value
                #print(col.values[0], "|", row.values[0], "|", round(val[0][0], 2))
                drop_cols.append(col.values[0])

    # Drop one of each pair of correlated columns
    drops = set(drop_cols)
    x = x.drop(columns=drops)
    print('Removed Columns {}'.format(drops))
    return (x,drops)

# %%
df_dropped, drops = remove_collinear_features(df_normalized,0.80)
# Out:
# Removed Columns {'int_d25_lamin', 'weighted_moments_central-0-2-1-2', 'moments_normalized-0-3-3', 'moments_central-3-1-0', 'weighted_moments-0-2-3-1', 'weighted_moments-2-3-0-1', 'weighted_moments_central-3-3-2-1', 'weighted_moments-1-2-0-2', 'moments_normalized-1-0-3', 'weighted_moments-0-1-2-0', 'moments_central-3-3-2', 'weighted_moments_central-3-0-2-2', 'moments-1-3-0', 'weighted_moments-2-2-2-1', 'weighted_moments_normalized-0-0-2-1', 'weighted_moments_central-0-1-2-2', 'weighted_moments_central-2-2-2-2', 'inertia_tensor-1-1', 'minor_axis_length', 'weighted_moments_central-0-0-0-2', 'lamin_foci_d_nearest_neighbor(verts)_variance', 'weighted_moments_normalized-0-3-2-0', 'moments_normalized-2-1-3', 'weighted_moments-3-1-3-2', 'weighted_local_centroid-0-1', 'moments_normalized-2-2-3', 'weighted_moments-1-2-2-2', 'weighted_moments-1-2-3-0', 'moments-2-2-1', 'moments-3-3-2', 'weighted_moments_central-3-3-0-2', 'weighted_moments_normalized-1-3-1-1', 'weighted_moments-1-3-3-1', 'dissimilarity_20', 'weighted_moments-0-3-1-0', 'moments-2-0-2', 'moments_normalized-2-0-3', 'weighted_moments_central-3-2-2-2', 'weighted_moments_central-1-2-1-1', 'moments-1-1-1', 'weighted_moments_central-0-2-0-2', 'hc_content_dna_content', 'weighted_moments_normalized-2-3-3-1', 'weighted_moments-3-2-3-2', 'ratio_lamin_boundary_patches_volume', 'weighted_moments_normalized-3-2-1-2', 'weighted_moments_normalized-3-0-0-0', 'weighted_moments_normalized-1-1-0-0', 'weighted_moments-1-0-3-0', 'weighted_moments_central-3-2-1-1', 'moments-0-3-3', 'weighted_moments-0-2-1-0', 'moments-2-2-3', 'weighted_moments-3-0-1-1', 'weighted_moments_central-2-1-2-1', 'moments_normalized-0-3-0', 'weighted_moments_central-3-0-2-1', 'weighted_moments_central-1-1-1-0', 'weighted_moments_normalized-0-2-2-1', 'weighted_moments_normalized-0-3-0-2', 'weighted_moments-1-0-1-0', 'rd_dapi_5', 'gamma_foci_d2b_variance', 'moments_central-2-2-2', 'moments-3-0-1', 'weighted_moments-0-0-3-2', 'weighted_moments_normalized-1-1-2-1', 'lamin_hole_d_nearest_neighbor(verts)_mean', 'weighted_moments_normalized-3-3-3-0', 'energy_1_lamin', 'weighted_moments_normalized-2-3-2-0', 'weighted_moments_central-1-2-2-0', 'moments_central-0-3-3', 'moments_normalized-1-3-0', 'moments_central-2-3-1', 'weighted_moments_central-1-3-1-0', 'weighted_moments_central-2-0-0-1', 'weighted_moments_normalized-0-2-1-0', 'weighted_moments-2-1-2-0', 'weighted_moments_normalized-1-2-0-0', 'energy_1', 'moments-3-3-3', 'weighted_moments-3-2-1-2', 'weighted_moments_central-3-0-3-1', 'weighted_moments-0-1-2-1', 'moments_central-3-0-3', 'asm_5_lamin', 'local_centroid-1', 'weighted_moments_central-3-1-1-1', 'moments-2-3-1', 'weighted_moments_central-1-1-2-0', 'weighted_moments-3-1-2-0', 'weighted_moments_central-2-3-1-0', 'energy_5', 'moments-0-1-1', 'weighted_moments_normalized-1-2-3-1', 'moments-2-3-3', 'weighted_moments-3-1-2-1', 'weighted_moments_central-3-3-2-0', 'lamin_foci_ratio_nearest_neighbor(verts)_variance_count', 'hc_area_ec_area', 'weighted_moments-2-0-1-1', 'gamma_foci_d_nearest_neighbor(verts)_variance', 'moments_normalized-2-1-0', 'weighted_moments_normalized-3-2-2-2', 'gamma_foci_ratio_nearest_neighbor_volume_variance', 'weighted_moments_normalized-3-1-2-0', 'moments_normalized-0-1-3', 'int_min_lamin', 'int_d75', 'moments_normalized-0-1-1', 'weighted_moments_central-3-2-2-1', 'weighted_moments_normalized-2-2-1-0', 'weighted_moments-2-1-0-1', 'weighted_moments_normalized-3-3-0-2', 'asm_1_lamin', 'moments_normalized-3-0-1', 'weighted_moments_normalized-3-2-0-0', 'weighted_moments_central-0-0-2-1', 'weighted_moments-3-1-3-0', 'moments_central-3-3-1', 'weighted_moments-2-2-0-0', 'weighted_moments_normalized-0-0-3-0', 'weighted_moments-0-1-1-1', 'weighted_moments-3-3-2-0', 'moments_normalized-2-3-0', 'weighted_moments_central-3-0-1-2', 'weighted_moments_normalized-3-1-0-1', 'moments_central-2-1-1', 'weighted_moments_central-3-2-0-0', 'inertia_tensor_eigvals-0', 'weighted_moments_central-1-3-3-1', 'moments_central-3- ...

# %%
print(len(drops))
df_dropped = pd.concat([df_dropped, condition], axis=1)
df_dropped.to_pickle('dataframe_dropped.pkl')
# Out:
# 812

# %%
all_possible_rfc(df_dropped, 'all_features', compute_pairs=False, n_jobs=96)
# Out:
# Average Train Accuracy: 1.0
# Average Accuracy: 0.5308126721763086

# %%
df = pd.read_pickle('dataframe_dropped.pkl')
min_sample_size = df.groupby('condition').size().min()
plt.figure(figsize=(10,6))
df['condition'] = pd.Categorical(df['condition'], categories=['tnfa_low', 'mcp_low', 'both_low', 'Control', 'tnfa_high', 'mcp_high', 'both_high', 'BSA'])
sns.barplot(data=df, x='condition', y='mean_intensity-2', hue='condition', dodge=False)
plt.legend().remove()
plt.title(f'Distribution of i80_i20_lamin per condition (n>{round(min_sample_size,-1)})')
plt.show()

# %%
df = pd.read_pickle('dataframe_dropped.pkl')
plt.figure(figsize=(10,6))
df['condition'] = pd.Categorical(df['condition'], categories=['tnfa_low', 'tnfa_high','mcp_low', 'mcp_high','both_low',  'both_high','Control',   'BSA'])
sns.barplot(data=df, x='condition', y='gamma_foci_count', hue='condition', dodge=False)
plt.title('Distribution of mean_intensity-1 per condition')
plt.show()

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
